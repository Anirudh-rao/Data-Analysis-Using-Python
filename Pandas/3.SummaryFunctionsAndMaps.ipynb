# %% [markdown]
# # Introduction
#
# In the last tutorial , we have learned how to select relevant data out of a DataFrame or Series. Plucking the right data of our data representation is critical to getting work done, as we demostreted in the excercises.
#
# However , the data does not always come out of memory in the format we want it in right out of the bat . Sometimes we have to do some work ourselves to reformat it for the task at hand. This tutorial will cover differnt  operations we can apply to our data to get the input "just right".

# %%
import pandas as pd

review = pd.read_csv('Data/winemag-data-130k-v2.csv'
                    ,index_col = 0)
pd.set_option('display.max_rows',5)

# %%
review
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# # 1. Summary Functions
#
# Pandas provides many simple "summary functions " which restructure the data in some useful way. For Example consider the `discribe()` method:

# %%
review.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# ...              ...            ...
# 75%        91.000000      42.000000
# max       100.000000    3300.000000
#
# [8 rows x 2 columns]

# %% [markdown]
# This method generates a high-level summary of the attributes of the given column. It is type-aware, meaning that its output changes based on the data type of the input. The output above only makes sense for numerical data; for string data here's what we get:

# %%
review.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %% [markdown]
# If you want to get some particular simple summary statistic about a column in a DataFrame or a Series, there is usually a helpful pandas function that makes it happen.
#
# For example, to see the mean of the points allotted (e.g. how well an averagely rated wine does), we can use the `mean()` function:

# %%
review.points.mean()
# Out:
# np.float64(88.44713820775404)

# %% [markdown]
# To see a list of unique values we can use the `unique()` function:

# %%
review.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %% [markdown]
# # Map
#
# A **Map** term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values. In data science we oftern have a need for creating representations from existing data or for transforming data from the format it is now to format that we want it to be in later. Maps are what handle this work, making them extremly important for getting your work done.
#
# There are two mapping methods that we will often use :
#
# 1. *map()* is the first and slightly simple one. For example, suppose that we wanted to remean the scores the wines received to 0. we can do this as follows:

# %%
review_point_mean = review.points.mean()
review.points.map(lambda p:p - review_point_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.
#
# *apply()* is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

# %%
def remean_points(row):
    row.points = row.points  - review_point_mean
    return row
review.apply(remean_points, axis = 'columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# If we had called `reviews.apply()` with `axis='index'`, then instead of passing a function to transform each row, we would need to give a function to transform each column.
#
# Note that `map()` and `apply()` return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on. If we look at the first row of reviews, we can see that it still has its original points value.

# %%
review.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# Pandas provides many common mapping operations as built-ins. For example, here's a faster way of remeaning our points column:

# %%
review_point_mean = review.points.mean()
review.points - review_point_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# In this code we are performing an operation between a lot of values on the left-hand side (everything in the Series) and a single value on the right-hand side (the mean value). Pandas looks at this expression and figures out that we must mean to subtract that mean value from every value in the dataset.
#
# Pandas will also understand what to do if we perform these operations between Series of equal length. For example, an easy way of combining country and region information in the dataset would be to do the following:

# %%
review.country + " - " + review.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# These operators are faster than `map()` or `apply()` because they use speed ups built into pandas. All of the standard Python operators (`>`, `<`, `==`, and so on) work in this manner.
#
# However, they are not as flexible as `map()` or `apply()`, which can do more advanced things, like applying conditional logic, which cannot be done with addition and subtraction alone.
